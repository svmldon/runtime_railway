# %% [markdown]
# Checked the distribution by taking n samples. Each sample was of
# size 10% of the population. Result showed that t distribution best fitted the result

# %%
# %run read_data.ipynb
# Out:
# read_data.ipynb:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "cell_type": "code",
# read_data.ipynb:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "source": [
# read_data.ipynb:12: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "import matplotlib\n",
# read_data.ipynb:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "from scipy.interpolate import Akima1DInterpolator\n",

# %%
# %run functions.ipynb

# %% [markdown]
# Normalization of column values

# %%
normal()

# %% [markdown]
# Generating new runtimes by taking average of 5 at a time

# %%
#Each rt_clt_XX_YY will have 58 block section data in moving average form
rt_clt_up_00 = []
rt_clt_up_01 = []
rt_clt_up_10 = []
rt_clt_up_11 = []
rt_clt_dn_00 = []
rt_clt_dn_01 = []
rt_clt_dn_10 = []
rt_clt_dn_11 = []
rt_clt = [rt_clt_up_00, rt_clt_up_01, rt_clt_up_10, rt_clt_up_11, rt_clt_dn_00, rt_clt_dn_01, rt_clt_dn_10, rt_clt_dn_11]

# %%
for j in range(8):
    for l in range(3,61):
        clt_values = []
        column1 = rt_names[j].iloc[:,l]
        column2 = column1.values
        column = [k for k in column2 if str(k) != 'nan']
        length = len(column)
        if (length<20):
            clt_values.append(np.nan)
            rt_clt[j].append(clt_values)
            continue
        for i in range(length):
            sample1 = random.sample(column, math.floor(length*0.1))
            clt_values.append(statistics.mean(sample1))
        rt_clt[j].append(clt_values)

# %% [markdown]
# len(rt_clt[0])

# %% [markdown]
#         mean = (column[i]+column[i+1]+column[i+2]+column[i+3]+column[i+4])/5
#         clt_values.append(mean)
#     clt_values.append((column[len(column)-4]+column[len(column)-3]+column[len(column)-2]+column[len(column)-1]+column[0])/5)
#     clt_values.append((column[len(column)-3]+column[len(column)-2]+column[len(column)-1]+column[0]+column[1])/5)
#     clt_values.append((column[len(column)-2]+column[len(column)-1]+column[0]+column[1]+column[2])/5)
#     clt_values.append((column[len(column)-1]+column[0]+column[1]+column[2]+column[3])/5)
#     rt_clt[j].append(clt_values)

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

total_rr = []
total_rr1 = []
for j in range(8):
    type_rr = []
    type_rr1 = []
    rr = rt_clt[j]
    for i in range(58):
        if (len(rr[i])<35):
            continue
        data = outlier(rr[i])
        type_rr.append(data)
        #sns.distplot(data)
        #plt.show()
    for g in type_rr:
        for h in g:
            type_rr1.append(h)
    sns.distplot(type_rr1)
    plt.show()
    #D, p = stats.kstest(type_rr1, 'norm')
    D, p = stats.shapiro(type_rr1)
    #k2, p = stats.normaltest(type_rr1)
    #a,b,c = stats.anderson(type_rr1, dist='norm')
    #print(a,b,c)
    print(p)
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(type_rr1)
    print(P_value1)
    total_rr.append(type_rr1)
for g in total_rr:
        for h in g:
            total_rr1.append(h)
sns.distplot(total_rr1)
plt.show()
#D, p = stats.kstest(total_rr1, 'norm')
D, p = stats.shapiro(total_rr1)
#k2, p = stats.normaltest(total_rr1)
#a,b,c = stats.anderson(total_rr1, dist='norm')
#print(a,b,c)
print(p)
dst = Distribution()
Dist_type1,P_value1 = dst.Fit(type_rr1)
print(P_value1)
# Out:
# 0.0
# alpha
# 1.1868500745100162e-112
# argus
# 0.0
# beta
# 1.3062960345993133e-99
# betaprime
# 1.3368494771931048e-121
# bradford
# 0.0
# burr
# 0.00032182412447808644
# burr12
# 0.0005996560447047408
# cauchy
# 1.0629896595240488e-302
# chi
# 2.4205969345217585e-140
# chi2
# 0.0
# crystalball
# 7.561540881439026e-104
# dgamma
# 1.0441263853043212e-24
# dweibull
# 9.670302116161583e-08
# expon
# 0.0
# exponnorm
# 3.4147369337252136e-101
# exponweib
# 8.338387156961861e-151
# exponpow
# 0.0
# f
# 8.641554525867961e-111
# fatiguelife
# 6.351565931879384e-98
# fisk
# 0.0005787288282001277
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0003393595776056252
# gennorm
# 2.0422815460123236e-12
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 3.48828537770934e-103
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 4.527855873745911e-09
# invgamma
# 2.067401250431386e-117
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.01655547856176145
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 2.448795605898069e-81
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0006779721761570557
# loggamma
# 4.856992246022707e-100
# loglaplace
# 1.652873085932315e-81
# lognorm
# 6.315938049296061e-110
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0003176131857178625
# moyal
# 0.0
# nakagami
# 3.883544493778051e-252
# ncx2
# 0.0
# nct
# 0.0
# norm
# 7.539818427684063e-104
# norminvgauss
# 4.562144101721873e-79
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 9.551660305836868e-101
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 9.455612687158584e-106
# t
# 0.07952370142277435
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.000979356902307849
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.07952370142277435
# 0.07952370142277435
# 0.0
# alpha
# 6.741975561586762e-225
# argus
# 0.0
# beta
# 9.106536142496277e-215
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 4.921629574609796e-35
# burr12
# 9.395059844553477e-39
# cauchy
# 5.080836993331146e-105
# chi
# 3.038137766334428e-241
# chi2
# 0.0
# crystalball
# 1.038048140229882e-214
# dgamma
# 7.689628293770267e-09
# dweibull
# 1.8990335698269594e-09
# expon
# 0.0
# exponnorm
# 3.6386841884450034e-217
# exponweib
# 5.326079419236999e-220
# exponpow
# 0.0
# f
# 1.9541383736108453e-224
# fatiguelife
# 2.3441371188107983e-215
# fisk
# 5.810298736698393e-38
# foldcauchy
# 7.909973959647394e-171
# foldnorm
# 0.0
# genlogistic
# 2.864124646734596e-37
# gennorm
# 1.447012295421381e-08
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 4.339384185664631e-228
# gengamma
# 6.825790034331333e-219
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 5.91286728684526e-13
# invgamma
# 7.021600758978821e-286
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 3.3306583253085536e-215
# johnsonsu
# 0.07804200298782865
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 4.5651965579590215e-09
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 7.398129228413047e-38
# loggamma
# 5.5495454370069416e-232
# loglaplace
# 1.3069414681650125e-09
# lognorm
# 1.8572231781585816e-214
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 4.2561159265478695e-39
# moyal
# 0.0
# nakagami
# 1.4923100815808767e-229
# ncx2
# 0.0
# nct
# 0.0
# norm
# 1.0260903336031448e-214
# norminvgauss
# 2.8463629258250715e-200
# pareto
# 0.0
# pearson3
# 4.3783505925427604e-217
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 1.0124878291548578e-204
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 5.357439084678506e-215
# recipinvgauss
# 4.7680245837538626e-284
# semicircular
# 0.0
# skewnorm
# 1.7882507105161955e-223
# t
# 0.0014343321618448238
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# johnsonsu
# 0.07804200298782865
# 0.07804200298782865
# 0.0
# alpha
# 7.345572521721642e-210
# argus
# 0.0
# beta
# 9.264952917642914e-207
# betaprime
# 1.420618297801133e-290
# bradford
# 0.0
# burr
# 2.0208909597865686e-24
# burr12
# 7.804624320294661e-21
# cauchy
# 6.1604390637159826e-139
# chi
# 2.6365806404441304e-277
# chi2
# 0.0
# crystalball
# 1.0189976391833331e-206
# dgamma
# 3.952829488453276e-11
# dweibull
# 5.5395966963800026e-11
# expon
# 0.0
# exponnorm
# 3.337696547638686e-175
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 3.1299397055927505e-211
# fatiguelife
# 3.7441566032517406e-207
# fisk
# 2.4349207265642167e-19
# foldcauchy
# 3.1903498331606667e-290
# foldnorm
# 0.0
# genlogistic
# 3.1723860223560626e-23
# gennorm
# 2.788671200899284e-16
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 2.811276057128578e-218
# gengamma
# 2.5112940301003406e-271
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 8.076231727235875e-08
# invgamma
# 7.678304e-318
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 2.9046944694588614e-207
# johnsonsu
# 0.0014413010448369242
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 5.506293371102421e-23
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 1.2789458626240628e-19
# loggamma
# 2.5320026402970403e-234
# loglaplace
# 4.2050848049638636e-23
# lognorm
# 5.464489918530302e-207
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.9625852872467992e-24
# moyal
# 0.0
# nakagami
# 2.152245176426618e-220
# ncx2
# 0.0
# nct
# 0.0
# norm
# 9.988893831504991e-207
# norminvgauss
# 2.160044860923873e-177
# pareto
# 0.0
# pearson3
# 1.765533365499529e-207
# powerlaw
# 0.0
# powerlognorm
# 3.3154630225530906e-206
# powernorm
# 1.005926864507486e-207
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 1.0496302502413116e-206
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 6.699377757939253e-204
# t
# 0.02762031473159072
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.02762031473159072
# 0.02762031473159072
# 0.0
# alpha
# 1.9662413435266148e-79
# argus
# 0.0
# beta
# 2.580663216835306e-60
# betaprime
# 2.3557242253186638e-160
# bradford
# 0.0
# burr
# 0.0033436710961467094
# burr12
# 0.0025111132758116484
# cauchy
# 2.928559034445223e-244
# chi
# 1.8785758334722554e-66
# chi2
# 0.0
# crystalball
# 2.8762407521631852e-64
# dgamma
# 3.1680589173119648e-12
# dweibull
# 1.2526303829972886e-09
# expon
# 0.0
# exponnorm
# 8.863842603967577e-61
# exponweib
# 1.6418433244021618e-61
# exponpow
# 0.0
# f
# 6.96606672197181e-60
# fatiguelife
# 6.1914281400751315e-59
# fisk
# 0.001995596321918888
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0026926930885842015
# gennorm
# 0.0038630010726417056
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 3.780577308601706e-233
# gamma
# 8.422539287838276e-61
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.00011982352535376462
# invgamma
# 3.2784807888654003e-98
# invgauss
# 3.750161989229889e-156
# invweibull
# 0.0
# johnsonsb
# 1.2474413195385634e-62
# johnsonsu
# 0.017562352411813
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 4.906996718327352e-53
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0034831869759244113
# loggamma
# 6.062809517550284e-76
# loglaplace
# 6.092683199728019e-54
# lognorm
# 2.325558874101285e-58
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.00437145961410453
# moyal
# 0.0
# nakagami
# 6.910299338364664e-60
# ncx2
# 0.0
# nct
# 0.0
# norm
# 2.8252292454753517e-64
# norminvgauss
# 1.401404542991431e-54
# pareto
# 0.0
# pearson3
# 1.3842232775111132e-60
# powerlaw
# 0.0
# powerlognorm
# 7.410354475296525e-58
# powernorm
# 1.1733268654857137e-65
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 6.860982360684981e-64
# recipinvgauss
# 7.412832067257305e-78
# semicircular
# 0.0
# skewnorm
# 2.4597837684703535e-60
# t
# 0.004154997935274588
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0896258735124684
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 3.5694576335281753e-233
# wrapcauchy
# nan
# tukeylambda
# 0.0896258735124684
# 0.0896258735124684
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 6.18636147635149e-281
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 5.812553103503004e-231
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 1.809631586802793e-215
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 8.416803027199489e-61
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# nan
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 2.6457999697319443e-33
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 5.980114523913016e-48
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 2.6457999697319443e-33
# 2.6457999697319443e-33
# 0.0
# alpha
# 3.4110842086823876e-203
# argus
# 0.0
# beta
# 8.756741203870616e-180
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 2.4350511871320944e-20
# burr12
# 1.5127015571801699e-18
# cauchy
# 9.359295118355919e-143
# chi
# 5.794216801996406e-221
# chi2
# 0.0
# crystalball
# 9.65512787336155e-190
# dgamma
# 9.090829122680567e-11
# dweibull
# 8.860952277797414e-09
# expon
# 0.0
# exponnorm
# 6.392549114610536e-184
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 1.8776458405271612e-194
# fatiguelife
# 5.719325148162901e-194
# fisk
# 1.8747878597823708e-17
# foldcauchy
# 1.216562116233405e-212
# foldnorm
# 0.0
# genlogistic
# 7.793838293156559e-20
# gennorm
# 1.7364713847704838e-15
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 2.8371717728282716e-197
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 1.979223926668845e-05
# invgamma
# 1.3453511866075624e-272
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 8.435274676546757e-177
# johnsonsu
# 0.003970205225726578
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 2.0551873629201033e-24
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 1.8474162934638268e-17
# loggamma
# 5.433982870213066e-176
# loglaplace
# 4.044704954094595e-25
# lognorm
# 5.82521703018066e-194
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 3.5217229552530565e-20
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 9.879868766621183e-190
# norminvgauss
# 9.72943862203881e-154
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 8.41155879910351e-171
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 8.484360481391615e-190
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 9.892376072274955e-190
# t
# 0.0567030714502565
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.0567030714502565
# 0.0567030714502565
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 3.410225885761154e-119
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 1.9162332978001138e-281
# dweibull
# 6.3958633183795745e-198
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 2.4340053809007594e-181
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 1.2763267213216605e-120
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 3.107783776449014e-42
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 1.089978571930519e-24
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 1.2019431138959141e-32
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 1.089978571930519e-24
# 1.089978571930519e-24
# 0.0
# alpha
# 4.327078683350899e-29
# argus
# 0.0
# beta
# 3.0736311665845076e-31
# betaprime
# 8.371658392108083e-72
# bradford
# 0.0
# burr
# 0.004763560158087133
# burr12
# 0.004336205178899165
# cauchy
# 4.3318970935678745e-300
# chi
# 0.0
# chi2
# 1.1268665474349134e-95
# crystalball
# 7.704539657782492e-32
# dgamma
# 4.018191744895905e-28
# dweibull
# 1.7782135783223483e-15
# expon
# 0.0
# exponnorm
# 2.062619986881236e-26
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 2.831491638898109e-30
# fatiguelife
# 5.052905443450562e-30
# fisk
# 0.003240510248987672
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0060565631749721635
# gennorm
# 5.210838184330503e-05
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 2.072994271057406e-148
# gamma
# 1.9011694159214956e-29
# gengamma
# 9.157764814959225e-34
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 5.254439641723758e-18
# invgamma
# 1.0378946689232544e-53
# invgauss
# 1.2744399808098919e-136
# invweibull
# 0.0
# johnsonsb
# 1.1492103831244068e-30
# johnsonsu
# 0.5177601918126096
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 6.326759424985658e-90
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.003799419312382868
# loggamma
# 9.217833853908049e-34
# loglaplace
# 9.652427589151833e-89
# lognorm
# 3.2007058593915003e-27
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.004836777666426281
# moyal
# 0.0
# nakagami
# 5.4785950510485314e-30
# ncx2
# 0.0
# nct
# 0.0
# norm
# 7.609801036051409e-32
# norminvgauss
# 1.7554456853943904e-35
# pareto
# 0.0
# pearson3
# 1.4913466163430812e-30
# powerlaw
# 0.0
# powerlognorm
# 5.3483025952664636e-33
# powernorm
# 1.4415571467961982e-32
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 7.855102266749008e-32
# recipinvgauss
# 2.3857369342100926e-35
# semicircular
# 0.0
# skewnorm
# 6.0212291962954364e-27
# t
# 0.14425468580389322
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 2.070011358104969e-148
# wrapcauchy
# nan
# johnsonsu
# 0.5177601918126096
# 0.5177601918126096
# 0.0
# alpha
# 4.327078683350899e-29
# argus
# 0.0
# beta
# 3.0736311665845076e-31
# betaprime
# 8.371658392108083e-72
# bradford
# 0.0
# burr
# 0.004763560158087133
# burr12
# 0.004336205178899165
# cauchy
# 4.3318970935678745e-300
# chi
# 0.0
# chi2
# 1.1268665474349134e-95
# crystalball
# 7.704539657782492e-32
# dgamma
# 4.018191744895905e-28
# dweibull
# 1.7782135783223483e-15
# expon
# 0.0
# exponnorm
# 2.062619986881236e-26
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 2.831491638898109e-30
# fatiguelife
# 5.052905443450562e-30
# fisk
# 0.003240510248987672
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0060565631749721635
# gennorm
# 5.210838184330503e-05
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 2.072994271057406e-148
# gamma
# 1.9011694159214956e-29
# gengamma
# 9.157764814959225e-34
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 5.254439641723758e-18
# invgamma
# 1.0378946689232544e-53
# invgauss
# 1.2744399808098919e-136
# invweibull
# 0.0
# johnsonsb
# 1.1492103831244068e-30
# johnsonsu
# 0.5177601918126096
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 6.326759424985658e-90
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.003799419312382868
# loggamma
# 9.217833853908049e-34
# loglaplace
# 9.652427589151833e-89
# lognorm
# 3.2007058593915003e-27
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.004836777666426281
# moyal
# 0.0
# nakagami
# 5.4785950510485314e-30
# ncx2
# 0.0
# nct
# 0.0
# norm
# 7.609801036051409e-32
# norminvgauss
# 1.7554456853943904e-35
# pareto
# 0.0
# pearson3
# 1.4913466163430812e-30
# powerlaw
# 0.0
# powerlognorm
# 5.3483025952664636e-33
# powernorm
# 1.4415571467961982e-32
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 7.855102266749008e-32
# recipinvgauss
# 2.3857369342100926e-35
# semicircular
# 0.0
# skewnorm
# 6.0212291962954364e-27
# t
# 0.14425468580389322
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 2.070011358104969e-148
# wrapcauchy
# nan
# johnsonsu
# 0.5177601918126096
# 0.5177601918126096

# %%
import re
value_all = []
for i in range(8):  
    runtime = rt_names[i]
    
    y = runtime.iloc[:,3:]
    y_value1 = y.values
    y_value2 = []
    for sublist in y_value1:
        for item in sublist:
            y_value2.append(item)
    y_value = [i for i in y_value2 if str(i) != 'nan']
    #print(len(y_value))
    y_value3 = outlier(y_value,len(y_value))
    value_all.append(y_value3)

value_all1 = []
for sublist in value_all:
        for item in sublist:
            value_all1.append(item) 
value_all2 = outlier(value_all1,len(value_all1))

# %%
    y = y[~y.isnull()]
    """if (type1=='00'):
        y = outlier(y,y_c_00)
    elif (type1=='01'):
        y = outlier(y,y_c_01)
    elif (type1=='10'):
        y = outlier(y,y_c_10)
    else:
        y = outlier(y,y_c_11)"""
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(y)
    #dst.Plot1(y)

# %%
#box_cox = value_all[0]
box_cox = value_all2

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
#x = stats.loggamma.rvs(5, size=500) + 5
prob = stats.probplot(box_cox, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')
ax2 = fig.add_subplot(212)
xt, _ = stats.boxcox(box_cox)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')
plt.show()
