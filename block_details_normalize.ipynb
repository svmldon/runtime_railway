# %% [markdown]
# No distribution fitting and multi modal

# %%
# %run read_data.ipynb
# Out:
# read_data.ipynb:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "cell_type": "code",
# read_data.ipynb:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "source": [
# read_data.ipynb:12: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "import matplotlib\n",
# read_data.ipynb:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "from scipy.interpolate import Akima1DInterpolator\n",

# %%
# %run functions.ipynb

# %% [markdown]
# Normalization of column values

# %%
normalize()

# %% [markdown]
# Generating new runtimes by taking average of 5 at a time

# %%
#Each rt_clt_XX_YY will have 58 block section data in moving average form
rt_clt_up_00 = []
rt_clt_up_01 = []
rt_clt_up_10 = []
rt_clt_up_11 = []
rt_clt_dn_00 = []
rt_clt_dn_01 = []
rt_clt_dn_10 = []
rt_clt_dn_11 = []
rt_clt = [rt_clt_up_00, rt_clt_up_01, rt_clt_up_10, rt_clt_up_11, rt_clt_dn_00, rt_clt_dn_01, rt_clt_dn_10, rt_clt_dn_11]

# %%
for j in range(8):
    for l in range(3,61):
        clt_values = []
        column1 = rt_names[j].iloc[:,l]
        column2 = column1.values
        column = [k for k in column2 if str(k) != 'nan']
        length = len(column)
        if (length<20):
            clt_values.append(np.nan)
            rt_clt[j].append(clt_values)
            continue
        for i in range(length):
            sample1 = random.sample(column, math.floor(length/2))
            clt_values.append(statistics.mean(sample1))
        rt_clt[j].append(clt_values)

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

total_rr = []
total_rr1 = []
for j in range(8):
    type_rr = []
    type_rr1 = []
    rr = rt_clt[j]
    for i in range(58):
        if (len(rr[i])<35):
            continue
        data = outlier(rr[i])
        type_rr.append(data)
        #sns.distplot(data)
        #plt.show()
    for g in type_rr:
        for h in g:
            type_rr1.append(h)
    sns.distplot(type_rr1)
    plt.show()
    #D, p = stats.kstest(type_rr1, 'norm')
    D, p = stats.shapiro(type_rr1)
    #k2, p = stats.normaltest(type_rr1)
    #a,b,c = stats.anderson(type_rr1, dist='norm')
    #print(a,b,c)
    print(p)
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(type_rr1)
    print(P_value1)
    total_rr.append(type_rr1)
for g in total_rr:
        for h in g:
            total_rr1.append(h)
sns.distplot(total_rr1)
plt.show()
#D, p = stats.kstest(total_rr1, 'norm')
D, p = stats.shapiro(total_rr1)
#k2, p = stats.normaltest(total_rr1)
#a,b,c = stats.anderson(total_rr1, dist='norm')
#print(a,b,c)
print(p)
dst = Distribution()
Dist_type1,P_value1 = dst.Fit(type_rr1)
print(P_value1)
# Out:
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 1.632451123507892e-229
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 2.142739255269389e-253
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 4.2948307059716355e-237
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 5.814059810463161e-232
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 1.538015359451118e-222
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 3.3337728575878874e-267
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 2.044343363558662e-253
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 2.0231257127139628e-249
# rice
# 1.4252123987531668e-229
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 3.849961284591497e-247
# weibull_max
# 0.0
# wrapcauchy
# nan
# gengamma
# 1.538015359451118e-222
# 1.538015359451118e-222
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 9.46359987829977e-263
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 1.8923764802215267e-261
# exponweib
# 8.92642987453853e-278
# exponpow
# 0.0
# f
# 4.6026197012582513e-303
# fatiguelife
# 2.500924732941715e-267
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 4.299022250461502e-214
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 1.4057540382574083e-306
# invweibull
# 0.0
# johnsonsb
# 5.494736125671621e-237
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 1.637967674e-315
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 2.9714e-319
# nakagami
# 0.0
# ncx2
# 5.426990047616008e-226
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 8.67970564344009e-274
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 9.875213451220573e-240
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 1.4591906842704099e-189
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# wald
# 1.4591906842704099e-189
# 1.4591906842704099e-189
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 1.5400880929676223e-288
# bradford
# 0.0
# burr
# 0.0
# burr12
# 9.446171174913352e-220
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 2e-323
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 3.6683503260567555e-224
# exponweib
# 1.540663362348696e-282
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 5.324628649341953e-249
# fisk
# 2.450247384758151e-294
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 5.921569831150687e-216
# genextreme
# 2.026e-321
# gamma
# 2e-323
# gengamma
# 1.6733295309554594e-279
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 3.1196220353986e-310
# invgauss
# 1.822420421018694e-268
# invweibull
# 2.36e-321
# johnsonsb
# 1.0214406785426996e-231
# johnsonsu
# 4.743094337123601e-279
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 2.8919764101053054e-279
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 4.518939670513448e-277
# pareto
# 0.0
# pearson3
# 3e-323
# powerlaw
# 0.0
# powerlognorm
# 9.128892950827093e-278
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 2.220355033015947e-245
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 1.297137477000412e-178
# weibull_min
# 1.71514873e-315
# weibull_max
# 0.0
# wrapcauchy
# nan
# wald
# 1.297137477000412e-178
# 1.297137477000412e-178
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
# 0.0
# alpha
# 2.6155951727695297e-43
# argus
# 0.0
# beta
# 1.731280599298658e-266
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 2.9349816962560184e-78
# burr12
# 1.866200759655614e-57
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 2.4811782041309984e-262
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 5.3184673543748345e-145
# exponweib
# 2.53944334284028e-93
# exponpow
# 0.0
# f
# 1.1015907698238366e-103
# fatiguelife
# 1.8811600334928157e-117
# fisk
# 2.019231346426788e-53
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 5.2072888739285123e-76
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 9.933170265651427e-79
# gamma
# 0.0
# gengamma
# 2.9915472518598358e-164
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 1.698419935304961e-79
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 5.88603647969213e-61
# invgauss
# 3.648332440508656e-120
# invweibull
# 1.0140382937452748e-78
# johnsonsb
# 0.0
# johnsonsu
# 2.5311799892017403e-75
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 5.892439226857908e-164
# lognorm
# 1.5943620257522634e-50
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 9.272160793138928e-77
# moyal
# 1.597781701363119e-89
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 7.103911312863655e-53
# norm
# 0.0
# norminvgauss
# 1.5557113691848942e-147
# pareto
# 0.0
# pearson3
# 2.295147349295301e-262
# powerlaw
# 0.0
# powerlognorm
# 2.79283564491067e-79
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 2.3836913336783836e-110
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 2.6155951727695297e-43
# 2.6155951727695297e-43
# 0.0
# alpha
# 6.373333442739251e-202
# argus
# 0.0
# beta
# 3.563892415367833e-271
# betaprime
# 1.6913515308438684e-194
# bradford
# 0.0
# burr
# 3.8063279176802505e-188
# burr12
# 1.0565229515517656e-149
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 5.229141362080912e-140
# exponweib
# 9.780795711377982e-197
# exponpow
# 0.0
# f
# 2.500114182869178e-184
# fatiguelife
# 2.1937838673779968e-182
# fisk
# 2.2645326557380367e-166
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 2.3782740011391816e-237
# genextreme
# 1.041958451942258e-189
# gamma
# 1.0520439671827806e-241
# gengamma
# 2.449148288507518e-219
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 2.9530773385786e-184
# invgauss
# 1.6425084796191507e-183
# invweibull
# 1.1276117542293953e-189
# johnsonsb
# 1.430306693324065e-214
# johnsonsu
# 1.0389804227989768e-182
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 1.6664990886973396e-183
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.246529395229918e-182
# moyal
# 1.112969452618146e-275
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 1.2450056423865755e-294
# norm
# 0.0
# norminvgauss
# 4.718641273309462e-183
# pareto
# 0.0
# pearson3
# 9.056780816607033e-242
# powerlaw
# 0.0
# powerlognorm
# 7.81123274519074e-189
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 1.0126762189946527e-186
# semicircular
# 0.0
# skewnorm
# 8.179834542292769e-201
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 4.463569201412797e-242
# weibull_max
# 0.0
# wrapcauchy
# nan
# exponnorm
# 5.229141362080912e-140
# 5.229141362080912e-140
# 0.0
# alpha
# 2.142157368094518e-283
# argus
# 0.0
# beta
# 7.560056675643624e-176
# betaprime
# 7.08921146394944e-293
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 1.4845772368843858e-222
# crystalball
# 0.0
# dgamma
# 2.9314378665730975e-297
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 2.1516129233612076e-184
# exponpow
# 8.29790715933959e-296
# f
# 3.0201838139868446e-226
# fatiguelife
# 1.0567586427831442e-282
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 1.7609908150016856e-264
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 1.2107523252808368e-187
# genextreme
# 6.647849345060312e-296
# gamma
# 1.4326506324193893e-222
# gengamma
# 2.7350112071111677e-193
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 7.433681657661791e-265
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 4.223012278184745e-293
# invgauss
# 7.90232831258613e-285
# invweibull
# 7.246196482296494e-296
# johnsonsb
# 1.1362359256922526e-195
# johnsonsu
# 2.771992176147958e-291
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 8.914570976327595e-222
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 4.71643667763701e-290
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 2.901431829086199e-302
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 6.90077375807657e-200
# nct
# 3.0056851558215347e-294
# norm
# 0.0
# norminvgauss
# 3.884063192365081e-211
# pareto
# 0.0
# pearson3
# 1.2324620323409095e-222
# powerlaw
# 0.0
# powerlognorm
# 2.4353728689602167e-215
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 2.0968030460593038e-280
# semicircular
# 0.0
# skewnorm
# 1.8178174311726472e-178
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 4.706279092646742e-255
# weibull_max
# 3.217523609429047e-261
# wrapcauchy
# nan
# beta
# 7.560056675643624e-176
# 7.560056675643624e-176
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
