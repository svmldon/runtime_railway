# %%
# %run read_data.ipynb
# Out:
# read_data.ipynb:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "cell_type": "code",
# read_data.ipynb:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "source": [
# read_data.ipynb:12: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "import matplotlib\n",
# read_data.ipynb:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "from scipy.interpolate import Akima1DInterpolator\n",

# %%
# %run functions.ipynb

# %% [markdown]
# Normalization of column values

# %%
normal()

# %% [markdown]
# Generating new runtimes by taking average of 5 at a time

# %%
#Each rt_clt_XX_YY will have 58 block section data in moving average form
rt_clt_up_00 = []
rt_clt_up_01 = []
rt_clt_up_10 = []
rt_clt_up_11 = []
rt_clt_dn_00 = []
rt_clt_dn_01 = []
rt_clt_dn_10 = []
rt_clt_dn_11 = []
rt_clt = [rt_clt_up_00, rt_clt_up_01, rt_clt_up_10, rt_clt_up_11, rt_clt_dn_00, rt_clt_dn_01, rt_clt_dn_10, rt_clt_dn_11]

# %%
for j in range(8):
    for l in range(3,61):
        clt_values = []
        column1 = rt_names[j].iloc[:,l]
        column2 = column1.values
        column = [k for k in column2 if str(k) != 'nan']
        length = len(column)
        if (length<20):
            clt_values.append(np.nan)
            rt_clt[j].append(clt_values)
            continue
        for i in range(length):
            sample1 = random.sample(column, math.floor(length/2))
            clt_values.append(statistics.mean(sample1))
        rt_clt[j].append(clt_values)

# %% [markdown]
# len(rt_clt[0])

# %% [markdown]
#         mean = (column[i]+column[i+1]+column[i+2]+column[i+3]+column[i+4])/5
#         clt_values.append(mean)
#     clt_values.append((column[len(column)-4]+column[len(column)-3]+column[len(column)-2]+column[len(column)-1]+column[0])/5)
#     clt_values.append((column[len(column)-3]+column[len(column)-2]+column[len(column)-1]+column[0]+column[1])/5)
#     clt_values.append((column[len(column)-2]+column[len(column)-1]+column[0]+column[1]+column[2])/5)
#     clt_values.append((column[len(column)-1]+column[0]+column[1]+column[2]+column[3])/5)
#     rt_clt[j].append(clt_values)

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

total_rr = []
total_rr1 = []
for j in range(8):
    type_rr = []
    type_rr1 = []
    rr = rt_clt[j]
    for i in range(58):
        if (len(rr[i])<35):
            continue
        data = outlier(rr[i])
        type_rr.append(data)
        #sns.distplot(data)
        #plt.show()
    for g in type_rr:
        for h in g:
            type_rr1.append(h)
    sns.distplot(type_rr1)
    plt.show()
    #D, p = stats.kstest(type_rr1, 'norm')
    D, p = stats.shapiro(type_rr1)
    #k2, p = stats.normaltest(type_rr1)
    #a,b,c = stats.anderson(type_rr1, dist='norm')
    #print(a,b,c)
    print(p)
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(type_rr1)
    print(P_value1)
    total_rr.append(type_rr1)
for g in total_rr:
        for h in g:
            total_rr1.append(h)
sns.distplot(total_rr1)
plt.show()
#D, p = stats.kstest(total_rr1, 'norm')
D, p = stats.shapiro(total_rr1)
#k2, p = stats.normaltest(total_rr1)
#a,b,c = stats.anderson(total_rr1, dist='norm')
#print(a,b,c)
print(p)
dst = Distribution()
Dist_type1,P_value1 = dst.Fit(type_rr1)
print(P_value1)
# Out:
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 8.56243830946013e-118
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.002433629738443638
# cauchy
# 4.900532804200522e-299
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 6.518624253078201e-112
# dgamma
# 1.1003935712071967e-13
# dweibull
# 2.998270199871613e-08
# expon
# 0.0
# exponnorm
# 2.3192763949593525e-109
# exponweib
# 3.878025869574815e-130
# exponpow
# 0.0
# f
# 3.434623958297276e-117
# fatiguelife
# 1.2173336009567508e-113
# fisk
# 0.0024970584695239817
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.004192629304680384
# gennorm
# 4.1887837935020546e-14
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 9.171193845405784e-121
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 2.3193890624008018e-05
# invgamma
# 9.281177402735214e-194
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 3.68589817949888e-122
# johnsonsu
# 0.19562238021949224
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 7.283147553236927e-70
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0025488370048499793
# loggamma
# 4.2132805174573825e-119
# loglaplace
# 9.427598624533421e-70
# lognorm
# 7.087664974980186e-116
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.003421109730987026
# moyal
# 0.0
# nakagami
# 4.866731430131012e-146
# ncx2
# 0.0
# nct
# 0.0
# norm
# 6.237749505746178e-112
# norminvgauss
# 1.1956735339494045e-283
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 2.5241603245534203e-225
# powernorm
# 3.6624675498405946e-117
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 3.459155177582844e-116
# t
# 0.5445498859671447
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.5445498859671447
# 0.5445498859671447
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 3.784433401185323e-64
# burr12
# 1.5679562059073813e-66
# cauchy
# 3.6915058466129874e-86
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 3.0052337808410257e-13
# dweibull
# 1.071486499284315e-12
# expon
# 0.0
# exponnorm
# 2.67e-322
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 1.448210352891084e-65
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 5.262921459251176e-64
# gennorm
# 3.2248656651635906e-13
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 1.183001080297989e-28
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.47356729749167187
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 2.483394048929293e-12
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 1.2975147075182829e-65
# loggamma
# 0.0
# loglaplace
# 1.104891923647238e-12
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.9634261435453613e-68
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 3.126759010430519e-284
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.3447449186884012
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# johnsonsu
# 0.47356729749167187
# 0.47356729749167187
# 0.0
# alpha
# 9.90772169191727e-295
# argus
# 0.0
# beta
# 1.383765575927764e-206
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 4.281853433655688e-22
# cauchy
# 3.000168885798946e-139
# chi
# 6.824077972067447e-221
# chi2
# 0.0
# crystalball
# 1.4463151266963788e-206
# dgamma
# 5.6922584193392226e-08
# dweibull
# 1.3614172264888519e-09
# expon
# 0.0
# exponnorm
# 1.4796359230257625e-181
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 1.9312436419722475e-212
# fatiguelife
# 8.219729319112189e-209
# fisk
# 4.718852611750482e-20
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 1.0378475004525736e-21
# gennorm
# 3.212451564392649e-17
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 2.021840607044053e-218
# gengamma
# 4.153032030193457e-226
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 3.8720493198086666e-07
# invgamma
# 6.33407756280767e-287
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 1.7412710251676336e-209
# johnsonsu
# 0.0014471205077672194
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 5.346132533336048e-24
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 3.7659770085581847e-20
# loggamma
# 0.0
# loglaplace
# 6.603329817272383e-24
# lognorm
# 2.2967201296344328e-225
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 9.324526169724944e-26
# moyal
# 0.0
# nakagami
# 5.909928591090606e-218
# ncx2
# 0.0
# nct
# 0.0
# norm
# 1.53490717891737e-206
# norminvgauss
# 2.6126787324570328e-238
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 2.5048448705940293e-205
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 1.5384739924313016e-206
# recipinvgauss
# 2.1886232886956755e-280
# semicircular
# 0.0
# skewnorm
# 9.214124980365605e-205
# t
# 0.01948127990467714
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.01948127990467714
# 0.01948127990467714
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 7.624798470171663e-93
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 1.6216930822509036e-07
# cauchy
# 3.2302799424653275e-216
# chi
# 4.656895643353676e-142
# chi2
# 1.0673020603914254e-195
# crystalball
# 7.533290781608926e-93
# dgamma
# 2.403563130554547e-07
# dweibull
# 0.001531752391286034
# expon
# 0.0
# exponnorm
# 1.4036192672182524e-97
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 6.044025091384976e-97
# fatiguelife
# 1.7740012978988149e-96
# fisk
# 3.1757780393042666e-07
# foldcauchy
# 0.0
# foldnorm
# 8.196382549232366e-93
# genlogistic
# 3.17767427447994e-06
# gennorm
# 8.35770340501141e-05
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 6.309282326047666e-95
# gengamma
# 2.3525506317309653e-125
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.1319979968765575
# invgamma
# 1.6079065396957471e-142
# invgauss
# 4.576996874257048e-304
# invweibull
# 0.0
# johnsonsb
# 1.329140443342117e-92
# johnsonsu
# 0.3604038163343133
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 2.0626899898819208e-39
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 3.0987071989729183e-07
# loggamma
# 3.8174225477503935e-97
# loglaplace
# 1.792453968067452e-39
# lognorm
# 1.792420231093532e-96
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 4.047838368499225e-06
# moyal
# 0.0
# nakagami
# 2.11722054713701e-102
# ncx2
# 0.0
# nct
# 0.0
# norm
# 8.08161754244294e-93
# norminvgauss
# 2.3150823632807045e-152
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 1.1354912123382898e-86
# powernorm
# 1.3507118975676315e-95
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 1.337518035819806e-92
# recipinvgauss
# 2.3451935713202382e-150
# semicircular
# 0.0
# skewnorm
# 2.077619164624249e-97
# t
# 0.054888838749728414
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 4.949017038275581e-300
# weibull_max
# 0.0
# wrapcauchy
# nan
# johnsonsu
# 0.3604038163343133
# 0.3604038163343133
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 6.006779645125338e-256
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 8.321355840320438e-259
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 1.3376904996460457e-78
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 5.211677470477941e-37
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 5.211677470477941e-37
# 5.211677470477941e-37
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 5.75484560178587e-72
# burr12
# 5.552407900475668e-41
# cauchy
# 1.2668393274572033e-127
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 3.5955103304123716e-13
# dweibull
# 8.958808306589665e-14
# expon
# 0.0
# exponnorm
# 2.7648438956284696e-294
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 1.4103141792371956e-37
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 1.0836027894981725e-36
# gennorm
# 3.1395733445770544e-22
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 7.43871102265923e-14
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.009171293800969605
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 1.7665622218938699e-13
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 6.84189655459106e-38
# loggamma
# 0.0
# loglaplace
# 1.7066710959434273e-13
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.513087824818945e-35
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.17524091329091687
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.007027781822634164
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.17524091329091687
# 0.17524091329091687
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 1.2490298605512478e-89
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 5.682487084928944e-195
# dweibull
# 1.8078786478719739e-121
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 2.6615194440641338e-80
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 1.3171960753447627e-302
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 3.383504142701927e-09
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 8.655105419778634e-240
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 2.9213673504786176e-234
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# nan
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# nan
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0008972438958595156
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# t
# 0.0008972438958595156
# 0.0008972438958595156
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 2.904053807409485e-30
# betaprime
# 8.99289143693522e-104
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.06371736098192063
# cauchy
# 3.7952244830334127e-286
# chi
# 5.2302081623130435e-42
# chi2
# 1.4295169512365804e-68
# crystalball
# 2.3515061837313768e-30
# dgamma
# 3.352913830569311e-25
# dweibull
# 2.988660380836052e-07
# expon
# 0.0
# exponnorm
# 5.8092794219427565e-28
# exponweib
# 4.0364167926436504e-30
# exponpow
# 0.0
# f
# 1.907402250036616e-30
# fatiguelife
# 3.7693236782359506e-38
# fisk
# 0.07299441180959615
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.09130968365644586
# gennorm
# 0.0025133885384452355
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 2.489655257120201e-145
# gamma
# 1.3938603141071108e-29
# gengamma
# 2.151907417598768e-43
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 1.7928648999330906e-14
# invgamma
# 7.3576335747479255e-65
# invgauss
# 7.481644794173982e-106
# invweibull
# 0.0
# johnsonsb
# 2.271661592002798e-30
# johnsonsu
# 0.2952892752109531
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 9.914574174808562e-84
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.059403085678379354
# loggamma
# 5.1144846122090004e-36
# loglaplace
# 7.580961383106714e-84
# lognorm
# 7.615591856634732e-33
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.08352256828840479
# moyal
# 0.0
# nakagami
# 8.435445898612868e-29
# ncx2
# 0.0
# nct
# 1.029178584939723e-194
# norm
# 2.3421299408393314e-30
# norminvgauss
# 2.8603748278465946e-56
# pareto
# 0.0
# pearson3
# 5.968185722513099e-30
# powerlaw
# 0.0
# powerlognorm
# 8.154671454629472e-28
# powernorm
# 3.472577316211526e-32
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 4.720671083344284e-30
# recipinvgauss
# 4.049004322938971e-55
# semicircular
# 0.0
# skewnorm
# 3.6170483737813195e-28
# t
# 0.40847621447680865
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.42089602457484565
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 4.653444169686144e-159
# weibull_max
# 2.32607703957313e-145
# wrapcauchy
# nan
# tukeylambda
# 0.42089602457484565
# 0.42089602457484565
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 2.904053807409485e-30
# betaprime
# 8.99289143693522e-104
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.06371736098192063
# cauchy
# 3.7952244830334127e-286
# chi
# 5.2302081623130435e-42
# chi2
# 1.4295169512365804e-68
# crystalball
# 2.3515061837313768e-30
# dgamma
# 3.352913830569311e-25
# dweibull
# 2.988660380836052e-07
# expon
# 0.0
# exponnorm
# 5.8092794219427565e-28
# exponweib
# 4.0364167926436504e-30
# exponpow
# 0.0
# f
# 1.907402250036616e-30
# fatiguelife
# 3.7693236782359506e-38
# fisk
# 0.07299441180959615
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.09130968365644586
# gennorm
# 0.0025133885384452355
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 2.489655257120201e-145
# gamma
# 1.3938603141071108e-29
# gengamma
# 2.151907417598768e-43
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 1.7928648999330906e-14
# invgamma
# 7.3576335747479255e-65
# invgauss
# 7.481644794173982e-106
# invweibull
# 0.0
# johnsonsb
# 2.271661592002798e-30
# johnsonsu
# 0.2952892752109531
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 9.914574174808562e-84
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.059403085678379354
# loggamma
# 5.1144846122090004e-36
# loglaplace
# 7.580961383106714e-84
# lognorm
# 7.615591856634732e-33
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.08352256828840479
# moyal
# 0.0
# nakagami
# 8.435445898612868e-29
# ncx2
# 0.0
# nct
# 1.029178584939723e-194
# norm
# 2.3421299408393314e-30
# norminvgauss
# 2.8603748278465946e-56
# pareto
# 0.0
# pearson3
# 5.968185722513099e-30
# powerlaw
# 0.0
# powerlognorm
# 8.154671454629472e-28
# powernorm
# 3.472577316211526e-32
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 4.720671083344284e-30
# recipinvgauss
# 4.049004322938971e-55
# semicircular
# 0.0
# skewnorm
# 3.6170483737813195e-28
# t
# 0.40847621447680865
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.42089602457484565
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 4.653444169686144e-159
# weibull_max
# 2.32607703957313e-145
# wrapcauchy
# nan
# tukeylambda
# 0.42089602457484565
# 0.42089602457484565

# %%
import re
value_all = []
for i in range(8):  
    runtime = rt_names[i]
    
    y = runtime.iloc[:,3:]
    y_value1 = y.values
    y_value2 = []
    for sublist in y_value1:
        for item in sublist:
            y_value2.append(item)
    y_value = [i for i in y_value2 if str(i) != 'nan']
    #print(len(y_value))
    y_value3 = outlier(y_value,len(y_value))
    value_all.append(y_value3)

value_all1 = []
for sublist in value_all:
        for item in sublist:
            value_all1.append(item) 
value_all2 = outlier(value_all1,len(value_all1))

# %%
    y = y[~y.isnull()]
    """if (type1=='00'):
        y = outlier(y,y_c_00)
    elif (type1=='01'):
        y = outlier(y,y_c_01)
    elif (type1=='10'):
        y = outlier(y,y_c_10)
    else:
        y = outlier(y,y_c_11)"""
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(y)
    #dst.Plot1(y)

# %%
#box_cox = value_all[0]
box_cox = value_all2

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
#x = stats.loggamma.rvs(5, size=500) + 5
prob = stats.probplot(box_cox, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')
ax2 = fig.add_subplot(212)
xt, _ = stats.boxcox(box_cox)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')
plt.show()
