# %%
# %run read_data_1point5.ipynb

cal_u_delay = pd.read_csv("cal_u_delay.csv",index_col=0)
cal_d_delay = pd.read_csv("cal_d_delay.csv",index_col=0)
comp_u_delay = pd.read_csv("comp_u_delay.csv",index_col=0)
comp_d_delay = pd.read_csv("comp_d_delay.csv",index_col=0)
mode_u_delay = pd.read_csv("mode_u_delay.csv",index_col=0)
mode_d_delay = pd.read_csv("mode_d_delay.csv",index_col=0)
wtt_u_delay = pd.read_csv("wtt_u_delay.csv",index_col=0)
wtt_d_delay = pd.read_csv("wtt_d_delay.csv",index_col=0)

cal_u_infra = pd.read_csv("cal_u_infra.csv",index_col=0)
cal_d_infra = pd.read_csv("cal_d_infra.csv",index_col=0)
comp_u_infra = pd.read_csv("comp_u_infra.csv",index_col=0)
comp_d_infra = pd.read_csv("comp_d_infra.csv",index_col=0)
mode_u_infra = pd.read_csv("mode_u_infra.csv",index_col=0)
mode_d_infra = pd.read_csv("mode_d_infra.csv",index_col=0)
wtt_u_infra = pd.read_csv("wtt_u_infra.csv",index_col=0)
wtt_d_infra = pd.read_csv("wtt_d_infra.csv",index_col=0)

# %%
# %run functionv2.ipynb

# %%
start_time = timeit.default_timer()

#Column sum of delay and extra infra utilisation
cal_u_delay_col = []
cal_d_delay_col = []
comp_u_delay_col = []
comp_d_delay_col = []
mode_u_delay_col = []
mode_d_delay_col = []
wtt_u_delay_col = []
wtt_d_delay_col = []

cal_u_infra_col = []
cal_d_infra_col = []
comp_u_infra_col = []
comp_d_infra_col = []
mode_u_infra_col = []
mode_d_infra_col = []
wtt_u_infra_col = []
wtt_d_infra_col = []

for j in range(3,61):
    # Add all the block delay values
    cal_u_delay_col_sum = []
    cal_d_delay_col_sum = []
    comp_u_delay_col_sum = []
    comp_d_delay_col_sum = []
    mode_u_delay_col_sum = []
    mode_d_delay_col_sum = []
    wtt_u_delay_col_sum = []
    wtt_d_delay_col_sum = []

    cal_u_infra_col_sum = []
    cal_d_infra_col_sum = []
    comp_u_infra_col_sum = []
    comp_d_infra_col_sum = []
    mode_u_infra_col_sum = []
    mode_d_infra_col_sum = []
    wtt_u_infra_col_sum = []
    wtt_d_infra_col_sum = []
    for l in range(54):
        if (cal_u_delay.iloc[l,j]!=0 and str(cal_u_delay.iloc[l,j])!='nan'):
            #print(cal_u_delay.iloc[l,j])
            cal_u_delay_col_sum.append(cal_u_delay.iloc[l,j])
        if (cal_d_delay.iloc[l,j]!=0 and str(cal_d_delay.iloc[l,j])!='nan'):
            cal_d_delay_col_sum.append(cal_d_delay.iloc[l,j])
        if (comp_u_delay.iloc[l,j]!=0 and str(comp_u_delay.iloc[l,j])!='nan'):    
            comp_u_delay_col_sum.append(comp_u_delay.iloc[l,j])
        if (comp_d_delay.iloc[l,j]!=0 and str(comp_d_delay.iloc[l,j])!='nan'):    
            comp_d_delay_col_sum.append(comp_d_delay.iloc[l,j])
        if (mode_u_delay.iloc[l,j]!=0 and str(mode_u_delay.iloc[l,j])!='nan'):    
            mode_u_delay_col_sum.append(mode_u_delay.iloc[l,j])
        if (mode_d_delay.iloc[l,j]!=0 and str(mode_d_delay.iloc[l,j])!='nan'): 
            mode_d_delay_col_sum.append(mode_d_delay.iloc[l,j])
        if (wtt_u_delay.iloc[l,j]!=0 and str(wtt_u_delay.iloc[l,j])!='nan'): 
            wtt_u_delay_col_sum.append(wtt_u_delay.iloc[l,j])
        if (wtt_d_delay.iloc[l,j]!=0 and str(wtt_d_delay.iloc[l,j])!='nan'): 
            wtt_d_delay_col_sum.append(wtt_d_delay.iloc[l,j])
            
        
        if (cal_u_infra.iloc[l,j]!=0 and str(cal_u_infra.iloc[l,j])!='nan'):
            cal_u_infra_col_sum.append(cal_u_infra.iloc[l,j])
        if (cal_d_infra.iloc[l,j]!=0 and str(cal_d_infra.iloc[l,j])!='nan'):
            cal_d_infra_col_sum.append(cal_d_infra.iloc[l,j])
        if (comp_u_infra.iloc[l,j]!=0 and str(comp_u_infra.iloc[l,j])!='nan'):    
            comp_u_infra_col_sum.append(comp_u_infra.iloc[l,j])
        if (comp_d_infra.iloc[l,j]!=0 and str(comp_d_infra.iloc[l,j])!='nan'):    
            comp_d_infra_col_sum.append(comp_d_infra.iloc[l,j])
        if (mode_u_infra.iloc[l,j]!=0 and str(mode_u_infra.iloc[l,j])!='nan'):    
            mode_u_infra_col_sum.append(mode_u_infra.iloc[l,j])
        if (mode_d_infra.iloc[l,j]!=0 and str(mode_d_infra.iloc[l,j])!='nan'):    
            mode_d_infra_col_sum.append(mode_d_infra.iloc[l,j])
        if (wtt_u_infra.iloc[l,j]!=0 and str(wtt_u_infra.iloc[l,j])!='nan'): 
            wtt_u_infra_col_sum.append(wtt_u_infra.iloc[l,j])
        if (wtt_d_infra.iloc[l,j]!=0 and str(wtt_d_infra.iloc[l,j])!='nan'): 
            wtt_d_infra_col_sum.append(wtt_d_infra.iloc[l,j])
    if (mean(cal_u_delay_col_sum)>0):
        cal_u_delay_col.append((mean(cal_u_delay_col_sum)))
    else:
        cal_u_delay_col.append(0)
    if (mean(cal_d_delay_col_sum)>0):
        cal_d_delay_col.append((mean(cal_d_delay_col_sum)))
    else:
        cal_d_delay_col.append(0)                       
    if (mean(comp_u_delay_col_sum)>0):
        comp_u_delay_col.append((mean(comp_u_delay_col_sum)))
    else:
        comp_u_delay_col.append(0)
    if (mean(comp_d_delay_col_sum)>0):
        comp_d_delay_col.append((mean(comp_d_delay_col_sum)))
    else:
        comp_d_delay_col.append(0)
    if (mean(mode_u_delay_col_sum)>0):
        mode_u_delay_col.append((mean(mode_u_delay_col_sum)))
    else:
        mode_u_delay_col.append(0)
    if (mean(mode_d_delay_col_sum)>0):
        mode_d_delay_col.append((mean(mode_d_delay_col_sum)))
    else:
        mode_d_delay_col.append(0)    
    if (mean(wtt_u_delay_col_sum)>0):
        wtt_u_delay_col.append((mean(wtt_u_delay_col_sum)))
    else:
        wtt_u_delay_col.append(0)
    #print((mean(wtt_d_delay_col_sum)))
    if (mean(wtt_d_delay_col_sum)>0):
        wtt_d_delay_col.append((mean(wtt_d_delay_col_sum))) 
    else:
        wtt_d_delay_col.append(0)       
    
                               
    if (mean(cal_u_infra_col_sum)>0):
        cal_u_infra_col.append((mean(cal_u_infra_col_sum)))
    else:
        cal_u_infra_col.append(0)
    if (mean(cal_d_infra_col_sum)>0):
        cal_d_infra_col.append((mean(cal_d_infra_col_sum)))
    else:
        cal_d_infra_col.append(0)                       
    if (mean(comp_u_infra_col_sum)>0):
        comp_u_infra_col.append((mean(comp_u_infra_col_sum)))
    else:
        comp_u_infra_col.append(0)
    if (mean(comp_d_infra_col_sum)>0):
        comp_d_infra_col.append((mean(comp_d_infra_col_sum))) 
    else:
        comp_d_infra_col.append(0)
    if (mean(mode_u_infra_col_sum)>0):
        mode_u_infra_col.append((mean(mode_u_infra_col_sum)))
    else:
        mode_u_infra_col.append(0)
    if (mean(mode_d_infra_col_sum)>0):
        mode_d_infra_col.append((mean(mode_d_infra_col_sum))) 
    else:
        mode_d_infra_col.append(0)    
    if (mean(wtt_u_infra_col_sum)>0):
        wtt_u_infra_col.append((mean(wtt_u_infra_col_sum)))
    else:
        wtt_u_infra_col.append(0)
    if (mean(wtt_d_infra_col_sum)>0):
        wtt_d_infra_col.append((mean(wtt_d_infra_col_sum)))  
    else:
        wtt_d_infra_col.append(0) 

       
  
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 2.3285853039706126

# %%
comp_u_delay_per = []
comp_d_delay_per = []
mode_u_delay_per = []
mode_d_delay_per = []
wtt_u_delay_per = []
wtt_d_delay_per = []

comp_u_infra_per = []
comp_d_infra_per = []
mode_u_infra_per = []
mode_d_infra_per = []
wtt_u_infra_per = []
wtt_d_infra_per = []
for i in range(58):
    comp_u_delay_per.append((comp_u_delay_col[i]-cal_u_delay_col[i])/cal_u_delay_col[i])
    comp_d_delay_per.append((comp_d_delay_col[i]-cal_d_delay_col[i])/cal_d_delay_col[i])
    mode_u_delay_per.append((mode_u_delay_col[i]-cal_u_delay_col[i])/cal_u_delay_col[i])
    mode_d_delay_per.append((mode_d_delay_col[i]-cal_d_delay_col[i])/cal_d_delay_col[i])
    wtt_u_delay_per.append((wtt_u_delay_col[i]-cal_u_delay_col[i])/cal_u_delay_col[i])
    wtt_d_delay_per.append((wtt_d_delay_col[i]-cal_d_delay_col[i])/cal_d_delay_col[i])
    
    comp_u_infra_per.append((comp_u_infra_col[i]-cal_u_infra_col[i])/cal_u_infra_col[i])
    comp_d_infra_per.append((comp_d_infra_col[i]-cal_d_infra_col[i])/cal_d_infra_col[i])
    mode_u_infra_per.append((mode_u_infra_col[i]-cal_u_infra_col[i])/cal_u_infra_col[i])
    mode_d_infra_per.append((mode_d_infra_col[i]-cal_d_infra_col[i])/cal_d_infra_col[i])
    wtt_u_infra_per.append((wtt_u_infra_col[i]-cal_u_infra_col[i])/cal_u_infra_col[i])
    wtt_d_infra_per.append((wtt_d_infra_col[i]-cal_d_infra_col[i])/cal_d_infra_col[i])

# %%
print("Mean delay per section in TCS computed runtime in UP direction",mean(comp_u_delay_per))
print("Mean delay per section in TCS computed runtime in DOWN direction",mean(comp_d_delay_per))
print("Mean delay per section in mode given as runtime in UP direction",mean(mode_u_delay_per))
print("Mean delay per section in mode given as runtime in DOWN direction",mean(mode_d_delay_per))
print("Mean delay per section in WTT runtime in UP direction",mean(wtt_u_delay_per))
print("Mean delay per section in WTT runtime in DOWN direction",mean(wtt_d_delay_per))
# Out:
# Mean delay per section in TCS computed runtime in UP direction 0.4340826722020759
# Mean delay per section in TCS computed runtime in DOWN direction 0.35285163215567544
# Mean delay per section in mode given as runtime in UP direction 0.2583641516097921
# Mean delay per section in mode given as runtime in DOWN direction 0.2502308442654953
# Mean delay per section in WTT runtime in UP direction 0.10445350187714705
# Mean delay per section in WTT runtime in DOWN direction 0.05941773060904557

# %%
print("Mean infra_excess_utilisation per section in TCS computed runtime in UP direction",mean(comp_u_infra_per))
print("Mean infra_excess_utilisation per section in TCS computed runtime in DOWN direction",mean(comp_d_infra_per))
print("Mean infra_excess_utilisation per section in mode given as runtime in UP direction",mean(mode_u_infra_per))
print("Mean infra_excess_utilisation per section in mode given as runtime in DOWN direction",mean(mode_d_infra_per))
print("Mean infra_excess_utilisation per section in WTT runtime in UP direction",mean(wtt_u_infra_per))
print("Mean infra_excess_utilisation per section in WTT runtime in DOWN direction",mean(wtt_d_infra_per))
# Out:
# Mean infra_excess_utilisation per section in TCS computed runtime in UP direction -0.3156011714125853
# Mean infra_excess_utilisation per section in TCS computed runtime in DOWN direction -0.3985699025802968
# Mean infra_excess_utilisation per section in mode given as runtime in UP direction -0.5937827857254536
# Mean infra_excess_utilisation per section in mode given as runtime in DOWN direction -0.6218257734254905
# Mean infra_excess_utilisation per section in WTT runtime in UP direction 0.134441403526696
# Mean infra_excess_utilisation per section in WTT runtime in DOWN direction 0.11917177753557029
