# %% [markdown]
# No distribution fitting and multi modal

# %%
# %run read_data.ipynb
# Out:
# read_data.ipynb:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "cell_type": "code",
# read_data.ipynb:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "source": [
# read_data.ipynb:12: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "import matplotlib\n",
# read_data.ipynb:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   "from scipy.interpolate import Akima1DInterpolator\n",

# %%
# %run functions.ipynb

# %% [markdown]
# Normalization of column values

# %%
standardize()

# %% [markdown]
# Generating new runtimes by taking average of 5 at a time

# %%
#Each rt_clt_XX_YY will have 58 block section data in moving average form
rt_clt_up_00 = []
rt_clt_up_01 = []
rt_clt_up_10 = []
rt_clt_up_11 = []
rt_clt_dn_00 = []
rt_clt_dn_01 = []
rt_clt_dn_10 = []
rt_clt_dn_11 = []
rt_clt = [rt_clt_up_00, rt_clt_up_01, rt_clt_up_10, rt_clt_up_11, rt_clt_dn_00, rt_clt_dn_01, rt_clt_dn_10, rt_clt_dn_11]

# %%
for j in range(8):
    for l in range(3,61):
        clt_values = []
        column1 = rt_names[j].iloc[:,l]
        column2 = column1.values
        column = [k for k in column2 if str(k) != 'nan']
        length = len(column)
        if (length<20):
            clt_values.append(np.nan)
            rt_clt[j].append(clt_values)
            continue
        for i in range(length):
            sample1 = random.sample(column, math.floor(length/2))
            clt_values.append(statistics.mean(sample1))
        rt_clt[j].append(clt_values)

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

total_rr = []
total_rr1 = []
for j in range(8):
    type_rr = []
    type_rr1 = []
    rr = rt_clt[j]
    for i in range(58):
        if (len(rr[i])<35):
            continue
        data = outlier(rr[i])
        type_rr.append(data)
        #sns.distplot(data)
        #plt.show()
    for g in type_rr:
        for h in g:
            type_rr1.append(h)
    sns.distplot(type_rr1)
    plt.show()
    #D, p = stats.kstest(type_rr1, 'norm')
    D, p = stats.shapiro(type_rr1)
    #k2, p = stats.normaltest(type_rr1)
    #a,b,c = stats.anderson(type_rr1, dist='norm')
    #print(a,b,c)
    print(p)
    dst = Distribution()
    Dist_type1,P_value1 = dst.Fit(type_rr1)
    print(P_value1)
    total_rr.append(type_rr1)
for g in total_rr:
        for h in g:
            total_rr1.append(h)
sns.distplot(total_rr1)
plt.show()
#D, p = stats.kstest(total_rr1, 'norm')
D, p = stats.shapiro(total_rr1)
#k2, p = stats.normaltest(total_rr1)
#a,b,c = stats.anderson(total_rr1, dist='norm')
#print(a,b,c)
print(p)
dst = Distribution()
Dist_type1,P_value1 = dst.Fit(type_rr1)
print(P_value1)
# Out:
# 0.0
# alpha
# 7.647853931131087e-292
# argus
# 0.0
# beta
# 1.231522208007933e-204
# betaprime
# 1.6132360786697e-297
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 1.4124787458743415e-263
# chi2
# 1.5549943509113465e-261
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 2.0784450566819504e-243
# exponpow
# 0.0
# f
# 1.3075727095802083e-292
# fatiguelife
# 2.852582412167251e-281
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 1.6889081522675883e-306
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 8.838161374582805e-293
# gamma
# 1.5675717288559576e-261
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 2.2939833360857984e-305
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 2.703115900424979e-290
# invgauss
# 5.0005066048706856e-282
# invweibull
# 8.21100737e-315
# johnsonsb
# 1.4364393265425592e-211
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 7.084480063155132e-266
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 2.2792356868540822e-286
# lomax
# 0.0
# maxwell
# 4.553184311026261e-237
# mielke
# 1.2273431221194e-311
# moyal
# 7.110698334538968e-263
# nakagami
# 1.3140692338287447e-263
# ncx2
# 0.0
# nct
# 1.7532960591317759e-279
# norm
# 0.0
# norminvgauss
# 3.399168225327077e-275
# pareto
# 0.0
# pearson3
# 1.4179754326951182e-261
# powerlaw
# 0.0
# powerlognorm
# 5.45314119682869e-219
# powernorm
# 1.2685120209752266e-201
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 1.0593202391335026e-280
# semicircular
# 0.0
# skewnorm
# 3.555681650032194e-273
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 8.654400560960634e-293
# wrapcauchy
# nan
# powernorm
# 1.2685120209752266e-201
# 1.2685120209752266e-201
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 6.436490555325772e-287
# exponweib
# 4.983386684022079e-308
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 1.0905460789633208e-306
# invgauss
# 2.9231875387525775e-306
# invweibull
# 0.0
# johnsonsb
# 3.257965241758003e-308
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 7.68796208370812e-309
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 7.5515076533311e-250
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# powerlognorm
# 7.5515076533311e-250
# 7.5515076533311e-250
# 0.0
# alpha
# 3.02384687e-316
# argus
# 0.0
# beta
# 0.0
# betaprime
# 8.574944685870987e-277
# bradford
# 0.0
# burr
# 4.571999310724e-312
# burr12
# 1.3491498912493284e-199
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 1.8411846806073267e-202
# exponweib
# 8.920713106596274e-280
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 1.7022130690294647e-261
# fisk
# 1e-323
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 7.864604919260268e-296
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 3.841010585362183e-279
# invgauss
# 5.572557283849932e-243
# invweibull
# 7.071352877400678e-296
# johnsonsb
# 1.2718907147053464e-285
# johnsonsu
# 2.561111666363077e-253
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 1.9083056489225555e-267
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 2.065795000455482e-292
# norm
# 0.0
# norminvgauss
# 1.6708382708261818e-257
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 1.1001121487143e-310
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 1.4953763184765746e-286
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# burr12
# 1.3491498912493284e-199
# 1.3491498912493284e-199
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
# 0.0
# alpha
# 6.227312265304175e-42
# argus
# 0.0
# beta
# 2.95983223955245e-268
# betaprime
# 2.0040598731306924e-79
# bradford
# 0.0
# burr
# 2.2682834244461567e-57
# burr12
# 4.566327229859254e-47
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 1.5443236199537278e-296
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 3.8565952161707735e-102
# exponweib
# 4.1157010827420615e-97
# exponpow
# 0.0
# f
# 1.2048763318823313e-55
# fatiguelife
# 1.7841475161646326e-137
# fisk
# 9.363841436175942e-53
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 1.1148802824728358e-56
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 7.320538813429312e-83
# gamma
# 1.0149833945680902e-180
# gengamma
# 2.0401571639083572e-94
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 3.9773699292771144e-59
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 7.672297147933714e-53
# invgauss
# 1.8717355726293385e-126
# invweibull
# 7.158768313251959e-83
# johnsonsb
# 2.2815018742863217e-51
# johnsonsu
# 1.7925088236526644e-61
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 4.1776814779951204e-91
# lognorm
# 1.6213050915547906e-46
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.5637611294913915e-288
# moyal
# 2.095919187273883e-115
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 8.220478456468913e-50
# norm
# 0.0
# norminvgauss
# 2.8705803720206787e-112
# pareto
# 0.0
# pearson3
# 1.5123991629549184e-296
# powerlaw
# 0.0
# powerlognorm
# 1.2680601019580055e-64
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 1.5039779428559224e-142
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 8.878664011050452e-251
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 3.491201343283343e-59
# wrapcauchy
# nan
# alpha
# 6.227312265304175e-42
# 6.227312265304175e-42
# 0.0
# alpha
# 2.2001480007120438e-195
# argus
# 0.0
# beta
# 0.0
# betaprime
# 3.3817613704575746e-307
# bradford
# 0.0
# burr
# 1.1684412011710692e-188
# burr12
# 2.6176351171287885e-149
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 6.575439552630031e-273
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 7.84131500490065e-125
# exponweib
# 2.448140033142801e-220
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 4.935227311530872e-239
# fisk
# 1.1330369691704655e-268
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 2.381732647160768e-295
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 2.207203340278543e-193
# gamma
# 6.656054325619529e-273
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 6.804433528597909e-297
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 4.271857276047029e-217
# invgauss
# 5.701556955833145e-237
# invweibull
# 2.088900947435593e-193
# johnsonsb
# 3.2001118724956404e-251
# johnsonsu
# 4.379811944967026e-165
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 4.285865763392987e-243
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 1.3165513612979097e-250
# lognorm
# 1.7443893267113026e-245
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.8844832881739063e-178
# moyal
# 8.407716418803082e-216
# nakagami
# 0.0
# ncx2
# 6.539966558273733e-273
# nct
# 5.901449389069613e-178
# norm
# 0.0
# norminvgauss
# 1.3724979757420365e-165
# pareto
# 0.0
# pearson3
# nan
# powerlaw
# 0.0
# powerlognorm
# 5.2961033902822054e-192
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 4.629278878315312e-242
# semicircular
# 0.0
# skewnorm
# 1.5343332044199198e-177
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# exponnorm
# 7.84131500490065e-125
# 7.84131500490065e-125
# 0.0
# alpha
# 4.8247711701278335e-244
# argus
# 0.0
# beta
# 0.0
# betaprime
# 1.3410097946580687e-203
# bradford
# 0.0
# burr
# 1.0943567639690262e-231
# burr12
# 7.177865987125306e-236
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 1.6849508372947127e-160
# crystalball
# 0.0
# dgamma
# 6.186390720164792e-214
# dweibull
# 1.149653722478782e-283
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 3.11775711145807e-191
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 2.906925288835545e-229
# fisk
# 4.123638331569764e-291
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 8.342134934428606e-234
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 3.6953565674950653e-252
# gamma
# 1.6654270718256772e-160
# gengamma
# 2.772664110473525e-187
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 1.582948116455762e-230
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 9.22396075e-316
# invgamma
# 6.702009288092989e-247
# invgauss
# 3.484824472900157e-232
# invweibull
# 3.8927868258484156e-252
# johnsonsb
# 5.645844280395249e-172
# johnsonsu
# 1.0770830834899084e-239
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# nan
# kstwobign
# 1.4124136915562816e-178
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 2.605764610613927e-240
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 1.4175570976675865e-214
# moyal
# 6.106539010980388e-294
# nakagami
# 0.0
# ncx2
# 1.4032134988465946e-167
# nct
# 1.6117454672478878e-245
# norm
# 0.0
# norminvgauss
# 1.6984523234075957e-230
# pareto
# 0.0
# pearson3
# 1.820146413223747e-160
# powerlaw
# 0.0
# powerlognorm
# 5.754655046402454e-179
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 8.361065828813413e-143
# rice
# 9.596884841922603e-143
# recipinvgauss
# 1.873769265440062e-226
# semicircular
# 0.0
# skewnorm
# 1.2917624888550572e-136
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 1.1264286148912508e-282
# weibull_max
# 1.1315727186365958e-190
# wrapcauchy
# nan
# skewnorm
# 1.2917624888550572e-136
# 1.2917624888550572e-136
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
# 0.0
# alpha
# 0.0
# argus
# 0.0
# beta
# 0.0
# betaprime
# 0.0
# bradford
# 0.0
# burr
# 0.0
# burr12
# 0.0
# cauchy
# 0.0
# chi
# 0.0
# chi2
# 0.0
# crystalball
# 0.0
# dgamma
# 0.0
# dweibull
# 0.0
# expon
# 0.0
# exponnorm
# 0.0
# exponweib
# 0.0
# exponpow
# 0.0
# f
# 0.0
# fatiguelife
# 0.0
# fisk
# 0.0
# foldcauchy
# 0.0
# foldnorm
# 0.0
# genlogistic
# 0.0
# gennorm
# 0.0
# genpareto
# 0.0
# genexpon
# 0.0
# genextreme
# 0.0
# gamma
# 0.0
# gengamma
# 0.0
# genhalflogistic
# 0.0
# gilbrat
# 0.0
# gompertz
# 0.0
# gumbel_r
# 0.0
# gumbel_l
# 0.0
# halfcauchy
# 0.0
# halflogistic
# 0.0
# halfnorm
# 0.0
# halfgennorm
# 0.0
# hypsecant
# 0.0
# invgamma
# 0.0
# invgauss
# 0.0
# invweibull
# 0.0
# johnsonsb
# 0.0
# johnsonsu
# 0.0
# kappa4
# 0.0
# kappa3
# 0.0
# ksone
# 0.0
# kstwobign
# 0.0
# laplace
# 0.0
# levy
# 0.0
# levy_l
# 0.0
# logistic
# 0.0
# loggamma
# 0.0
# loglaplace
# 0.0
# lognorm
# 0.0
# lomax
# 0.0
# maxwell
# 0.0
# mielke
# 0.0
# moyal
# 0.0
# nakagami
# 0.0
# ncx2
# 0.0
# nct
# 0.0
# norm
# 0.0
# norminvgauss
# 0.0
# pareto
# 0.0
# pearson3
# 0.0
# powerlaw
# 0.0
# powerlognorm
# 0.0
# powernorm
# 0.0
# rdist
# 0.0
# reciprocal
# 0.0
# rayleigh
# 0.0
# rice
# 0.0
# recipinvgauss
# 0.0
# semicircular
# 0.0
# skewnorm
# 0.0
# t
# 0.0
# trapz
# 0.0
# triang
# 0.0
# truncexpon
# 0.0
# truncnorm
# 0.0
# tukeylambda
# 0.0
# vonmises
# 0.0
# vonmises_line
# 0.0
# wald
# 0.0
# weibull_min
# 0.0
# weibull_max
# 0.0
# wrapcauchy
# nan
# alpha
# 0.0
# 0.0
